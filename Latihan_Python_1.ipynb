# %% [markdown]
# <a href="https://colab.research.google.com/github/BahiyahOthman/LatihanPython2026/blob/main/Latihan_Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Latihan Pengukuhan Python (Pembolehubah, Pengujian, Pengulangan)

# %% [markdown]
# Topik 1 : Pembolehubah

# %% [markdown]
# Soalan 1
#
# # Isikan tempat kosong
# nama = ___
#
# bandar = ___
#
# # Hasilkan paparan seperti di bawah
# Nama saya ialah **nama **dan saya tinggal **bandar**
#
# Hasilkan code anda di bahagian code di bawah

# %%
#Tulis kod anda di sini

# %% [markdown]
# Soalan 2
#
# Diberi
# panjang = 50
# lebar = 5
#
# Kirakan luas (*formula: panjang x lebar*)
#
# Paparkan seperti berikut
#
# Luas segiempat ialah :

# %%
#Tulis kod anda di sini

# %% [markdown]
# Soalan 3
#
# Betulkan ralat pada segmen kod berikut

# %%
# BETULKAN KOD DI BAWAH
jenama kereta = "Proton Saga"
Print("Kereta pertama saya ialah" + jenama kereta)

# %% [markdown]
# Soalan 4:
#
# Kira Harga Diskaun
# Tugasan: Tulis satu kod lengkap dari awal.
#
# 1. Cipta pembolehubah harga_asal dan berikan nilai 150.
#
# 2. Cipta pembolehubah diskaun dan berikan nilai 30 (mewakili RM30).
#
# 3. Kira harga_akhir (harga asal tolak diskaun).
#
# 4. Paparkan output seperti ini: Harga selepas diskaun ialah RM 120.

# %%
#Tulis kod penuh anda di sini

# %% [markdown]
# Topik 2 : Pengujian if - elif - else

# %% [markdown]
# Soalan 1
#
# markah = 75
#
# Syarat pengujian
#
# markah >= 80
#     Gred: Cemerlang
#
# markah >= 50
#     Gred: Lulus
#
# markah < 50
#     Gred: Gagal

# %%
#Tulis kod penuh anda di sini

# %% [markdown]
# Soalan 2
#
# Betulkan ralat pada segmen kod berikut

# %%
# BETULKAN KOD DI BAWAH
nombor = -5

if nombor > 0
    print("Nombor Positif")
else if nombor < 0:
    print("Nombor Negatif")
else:
print("Nombor Sifar")

# %% [markdown]
# Soalan 3
#
# Betulkan ralat pada segmen kod berikut

# %%
# BETULKAN KOD DI BAWAH
suhu = 39.5

if suhu >= 37.5:
    print("Status: Demam Biasa")
elif suhu >= 39.0:
    print("Status: Demam Kritikal!")
else:
    print("Status: Sihat")

# %% [markdown]
# Soalan 4: Sistem Tiket Zoo
#
# Tugasan: Tulis satu kod lengkap berdasarkan situasi berikut:
#
# 1. Cipta satu pembolehubah umur_pengunjung (contoh: letak nilai 65).
#
# 2. Jika umur di bawah 12 tahun, paparkan Harga tiket: RM5.
#
# 3. Jika umur 60 tahun dan ke atas, paparkan Harga tiket: RM10.
#
# 4. Bagi umur lain (antara 12 hingga 59), paparkan Harga tiket: RM15.

# %%
# Tulis kod penuh anda di sini

# %% [markdown]
# Topik 3 : Gelung

# %% [markdown]
# Soalan 1
#
# Lengkapkan fungsi range() di bawah supaya kod dapat mencetak nombor 1 hingga 5.
#
# for i in range(___, ___):
#
#     print("Nombor:", i)

# %%
# Tulis kod anda di sini

# %% [markdown]
# Soalan 2
#
# Betulkan ralat di bawah

# %%
# BETULKAN KOD DI BAWAH
for i range(3)
print("Sila bangun!")

# %% [markdown]
# Soalan 3
#
# Tulis satu kod menggunakan gelung for in range untuk menghasilkan paparan Sifir 5 dari 1 hingga 5 seperti di bawah:
#
# 1 x 5 = 5
#
# 2 x 5 = 10
#
# 3 x 5 = 15
#
# 4 x 5 = 20
#
# 5 x 5 = 25

# %%
# Tulis kod penuh anda di sini
